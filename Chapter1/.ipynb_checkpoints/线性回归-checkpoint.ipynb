# %%
# %matplotlib inline
import torch
import random
from d2l import torch as d2l

# %%
def synthetic_data (w,b,num_examples):#生成数据
    """生成 y = Xw +b + 噪声"""
    X=torch.normal(0,1,(num_examples,len(w)))#num_examples个样本，w行的向量
    y=torch.matmul(X,w)+b
    y+=torch.normal(0,0.01,y.shape)
    return X,y.reshape((-1,1))
    
true_w=torch.tensor([2,-3.4])
true_b=4.2
features,labels= synthetic_data(true_w,true_b,1000)

# %%
print('features:',features[0],'\nlabel:',labels[0])
# Out:
# features: tensor([-0.1131, -1.0443])
# label: tensor([7.5442])

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:,1].detach().numpy(),labels.detach().numpy(),1);

# %%
def data_iter(batch_size,features,labels):
    num_examples=len(features)
    indices=list(range(num_examples))
    random.shuffle(indices)
    for i in range(0,num_examples,batch_size):
        batch_indices=torch.tensor(indices[i:min(i+batch_size,num_examples)])
        yield features[batch_indices],labels[batch_indices]
batch_size=10
for X,y in data_iter(batch_size,features,labels):
    print(X,'\n',y)
    break
# Out:
# tensor([[ 1.0344,  0.4494],
#         [ 0.4504, -0.9463],
#         [ 0.2384,  0.2723],
#         [-0.9641, -0.2754],
#         [-0.9797,  1.3865],
#         [ 0.9706, -0.2866],
#         [ 0.4992,  0.3010],
#         [ 0.1501, -1.0839],
#         [ 1.0682,  0.2898],
#         [ 1.3544,  0.0742]])
#  tensor([[ 4.7392],
#         [ 8.3312],
#         [ 3.7443],
#         [ 3.2044],
#         [-2.4744],
#         [ 7.1028],
#         [ 4.1761],
#         [ 8.1920],
#         [ 5.3598],
#         [ 6.6658]])

# %%
w=torch.normal(0,0.01,size=(2,1),requires_grad=True)
b=torch.zeros(1,requires_grad=True)

# %%
def linreg(X,w,b):
    """线性回归模型"""
    return torch.matmul(X,w) +b

# %%
def squared_loss(y_hat,y):
    """均方损失"""
    return (y_hat - y.reshape(y_hat.shape))**2/2

# %%
def sgd(params,lr,batch_size):
    """小批量随机梯度下降"""
    with torch.no_grad():#不需要计算梯度
        for param in params:
            param -= lr*param.grad/batch_size
            param.grad.zero_()#梯度设为0

# %%
lr = 0.03
num_epoches=3

for epoch in range(num_epoches):
    for X,y in data_iter(batch_size,features,labels):
        l=squared_loss(linreg(X,w,b),y)
        l.sum().backward()
        sgd([w,b],lr,batch_size)
    with torch.no_grad():
        train_l=squared_loss(linreg(features,w,b),labels)
        print(f'epoch{epoch+1},loss{float(train_l.mean()):f}')
# Out:
# epoch1,loss0.042387
# epoch2,loss0.000169
# epoch3,loss0.000049

# %%
print(f'w的估计误差：{true_w-w.reshape(true_w.shape)}')
print(f'b的估计误差：{true_b-b}')
# Out:
# w的估计误差：tensor([4.4465e-05, 7.1764e-05], grad_fn=<SubBackward0>)
# b的估计误差：tensor([0.0004], grad_fn=<RsubBackward1>)
